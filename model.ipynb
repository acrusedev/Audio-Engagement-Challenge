# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import VotingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# === Load data ===
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# === Handle missing numeric columns ===
for col in ["Episode_Length_minutes", "Guest_Popularity_percentage"]:
    train[col] = train[col].fillna(train.groupby("Genre")[col].transform("median"))
    test[col] = test[col].fillna(test.groupby("Genre")[col].transform("median"))

# === Encode categorical ===
label_cols = ["Genre", "Publication_Day", "Publication_Time", "Episode_Sentiment"]
for col in label_cols:
    le = LabelEncoder()
    combined = pd.concat([train[col], test[col]], axis=0).astype(str)
    le.fit(combined)
    train[col] = le.transform(train[col].astype(str))
    test[col] = le.transform(test[col].astype(str))

# Frequency encode Podcast_Name
for df in [train, test]:
    freq = df["Podcast_Name"].value_counts().to_dict()
    df["Podcast_Name_freq"] = df["Podcast_Name"].map(freq)
df.drop(columns=["Podcast_Name", "Episode_Title"], inplace=True)

# === Log-transform numeric features (variance stabilizing) ===
for col in ["Episode_Length_minutes", "Host_Popularity_percentage", "Guest_Popularity_percentage"]:
    train[f"log_{col}"] = np.log1p(train[col])
    test[f"log_{col}"] = np.log1p(test[col])

# === Feature interactions ===
train["Ads_per_minute"] = train["Number_of_Ads"] / (train["Episode_Length_minutes"] + 1e-6)
test["Ads_per_minute"] = test["Number_of_Ads"] / (test["Episode_Length_minutes"] + 1e-6)

train["HostGuest_mean"] = (train["Host_Popularity_percentage"] + train["Guest_Popularity_percentage"]) / 2
test["HostGuest_mean"] = (test["Host_Popularity_percentage"] + test["Guest_Popularity_percentage"]) / 2

# === Prepare train/test matrices ===
X = train.drop(columns=["id", "Listening_Time_minutes"])
y = train["Listening_Time_minutes"]
X_test = test.drop(columns=["id"])

# === Log-transform target (reduces std) ===
y_log = np.log1p(y)

# === Models ===
xgb = XGBRegressor(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=7,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.5,
    random_state=42,
    n_jobs=-1
)

lgb = LGBMRegressor(
    n_estimators=500,
    learning_rate=0.04,
    num_leaves=64,
    feature_fraction=0.8,
    bagging_fraction=0.8,
    reg_lambda=1.2,
    random_state=42,
    n_jobs=-1
)

cat = CatBoostRegressor(
    iterations=600,
    depth=8,
    learning_rate=0.05,
    l2_leaf_reg=3.0,
    random_seed=42,
    verbose=False
)

model = VotingRegressor([("xgb", xgb), ("lgb", lgb), ("cat", cat)])
model.fit(X, y_log)

# === Predict & reverse log ===
preds_log = model.predict(X_test)
preds = np.expm1(preds_log)

# === Adjust mean to match training mean (≈ 45.43) ===
target_mean = 45.4374
pred_mean = preds.mean()
preds = preds * (target_mean / pred_mean)

# === Save submission ===
submission = pd.DataFrame({
    "id": test["id"],
    "Listening_Time_minutes": preds
})
submission.to_csv("submission.csv", index=False)

print("✅ Submission file created successfully!")
print("Final submission stats:")
print(submission.describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/share/mise/installs/python/3.13.7/lib/python3.13/site-packages/xgboost/data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 86
#      76 cat = CatBoostRegressor(
#      77     iterations=600,
#      78     depth=8,
#    (...)     82     verbose=False
#      83 )
#      85 model = VotingRegressor([("xgb", xgb), ("lgb", lgb), ("cat", cat)])
# ---> 86 model.fit(X, y_log)
#      88 # === Predict & reverse log ===
#      89 preds_log = model.predict(X_test)
#
# ...
